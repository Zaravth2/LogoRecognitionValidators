# %% [markdown]
# Notebook by Zara

# %% [markdown]
# #### ``You Only Look Once``

# %% [markdown]
# The YOLO model is another convolutional neural network used for object recognition, offering real-time evaluation unlike other algorithms such as SDD and R-CNN. It divided the input image into grids and assigns each grid the responsibility of detecting objects whose midpoint falls within it.
#
# The model predicts target frames for each grid, with each frame represented by five parameters: the coordinates of the center point (x, y), width (w), height (h), and a confidence score (si). The confidence score measures the accuracy of the predicted frame compared to the real frame.

# %%
# import libraries 
import pandas as pd
import numpy as np
import os
import cv2
import tensorflow as tf
from tensorflow.keras import layers

# %% [markdown]
# #### **``Data preparation``**

# %% [markdown]
# Read the CSV file

# %%
data = pd.read_csv('/Users/zaravanthoff/Desktop/MasterProject/Datasets/PublicDataset/flickr_logos_27_dataset/flickr_logos_27_dataset_training_set_annotation.txt', sep='\s+',header=None)

# %%
data
# Out:
#                    0       1  2    3    4    5    6
# 0      144503924.jpg  Adidas  1   38   12  234  142
# 1     2451569770.jpg  Adidas  1  242  208  413  331
# 2      390321909.jpg  Adidas  1   13    5   89   60
# 3     4761260517.jpg  Adidas  1   43  122  358  354
# 4     4763210295.jpg  Adidas  1   83   63  130   93
# ...              ...     ... ..  ...  ...  ...  ...
# 4531  2126991906.jpg   Yahoo  6   15    6  253   54
# 4532   217288720.jpg   Yahoo  6  136  161  304  222
# 4533  2472817996.jpg   Yahoo  6    2    4  499  106
# 4534  2514220918.jpg   Yahoo  6    1   69  342  157
# 4535   386891249.jpg   Yahoo  6  156   10  310   49
#
# [4536 rows x 7 columns]

# %%
print(data.dtypes)
# Out:
# 0    object
# 1    object
# 2     int64
# 3     int64
# 4     int64
# 5     int64
# 6     int64
# dtype: object

# %%
# # # Convert column 0 to float
# # data[0] = pd.to_numeric(data[0], errors='coerce')

# # Convert column 1 to float
# data[1] = pd.to_numeric(data[1], errors='coerce')

# # Convert labels column to int
# data[2] = data[2].astype(int)

# # Check the data types after conversion
# print(data.dtypes)

# %%
# Extract classes from the second column
classes = data[2]

# Count the number of unique classes
num_classes = len(classes.unique())

print("Number of classes:", num_classes)
# Out:
# Number of classes: 6

# %%
data
# Out:
#                    0       1  2    3    4    5    6
# 0      144503924.jpg  Adidas  1   38   12  234  142
# 1     2451569770.jpg  Adidas  1  242  208  413  331
# 2      390321909.jpg  Adidas  1   13    5   89   60
# 3     4761260517.jpg  Adidas  1   43  122  358  354
# 4     4763210295.jpg  Adidas  1   83   63  130   93
# ...              ...     ... ..  ...  ...  ...  ...
# 4531  2126991906.jpg   Yahoo  6   15    6  253   54
# 4532   217288720.jpg   Yahoo  6  136  161  304  222
# 4533  2472817996.jpg   Yahoo  6    2    4  499  106
# 4534  2514220918.jpg   Yahoo  6    1   69  342  157
# 4535   386891249.jpg   Yahoo  6  156   10  310   49
#
# [4536 rows x 7 columns]

# %% [markdown]
# Parse the annotations to extract the file names, class labels, and bounding box coordinates

# %%
# Iterate through each row in the dataset
for index, row in data.iterrows():
    # Extract file name
    image_filename = row[0]  # Assuming the file name is in the first column
    
    # Extract class label
    class_label = row[1]  # Assuming the class label is in the second column
    
    # Extract bounding box coordinates
    x_min, y_min, x_max, y_max = row[2], row[3], row[4], row[5]  # Assuming bounding box coordinates are in columns 3 to 6
    
    # Print extracted information
    print(f"Image file name: {image_filename}")
    print(f"Class label: {class_label}")
    print(f"Bounding box coordinates: ({x_min}, {y_min}), ({x_max}, {y_max})")
# Out:
# Image file name: 144503924.jpg
# Class label: Adidas
# Bounding box coordinates: (1, 38), (12, 234)
# Image file name: 2451569770.jpg
# Class label: Adidas
# Bounding box coordinates: (1, 242), (208, 413)
# Image file name: 390321909.jpg
# Class label: Adidas
# Bounding box coordinates: (1, 13), (5, 89)
# Image file name: 4761260517.jpg
# Class label: Adidas
# Bounding box coordinates: (1, 43), (122, 358)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (1, 83), (63, 130)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (1, 91), (288, 125)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (1, 182), (63, 229)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (1, 192), (291, 225)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (1, 285), (61, 317)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (1, 285), (298, 324)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (1, 377), (292, 421)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (1, 383), (55, 416)
# Image file name: 1230939811.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 129), (326, 257)
# Image file name: 1230939811.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 137), (336, 243)
# Image file name: 2550056374.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 18), (2, 488)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 126), (252, 207)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 127), (324, 206)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 129), (109, 206)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 132), (176, 206)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 212), (111, 287)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 213), (180, 288)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 213), (253, 290)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 213), (327, 287)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 294), (109, 373)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 294), (327, 372)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 295), (252, 372)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 296), (179, 370)
# Image file name: 4061203382.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 155), (206, 241)
# Image file name: 4499338915.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 72), (20, 392)
# Image file name: 144503924.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 38), (12, 234)
# Image file name: 2451569770.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 242), (208, 413)
# Image file name: 390321909.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 13), (5, 89)
# Image file name: 4761260517.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 43), (122, 358)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 83), (63, 130)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 91), (288, 125)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 182), (63, 229)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 192), (291, 225)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 285), (61, 317)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 285), (298, 324)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 377), (292, 421)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (2, 383), (55, 416)
# Image file name: 2534155497.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 59), (1, 479)
# Image file name: 3007885565.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 221), (20, 476)
# Image file name: 4336482746.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 16), (194, 246)
# Image file name: 451265524.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 195), (179, 244)
# Image file name: 791925651.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 1), (3, 96)
# Image file name: 1230939811.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 129), (326, 257)
# Image file name: 1230939811.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 137), (336, 243)
# Image file name: 2550056374.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 18), (2, 488)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 126), (252, 207)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 127), (324, 206)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 129), (109, 206)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 132), (176, 206)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 212), (111, 287)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 213), (180, 288)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 213), (253, 290)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 213), (327, 287)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 294), (109, 373)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 294), (327, 372)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 295), (252, 372)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 296), (179, 370)
# Image file name: 4061203382.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 155), (206, 241)
# Image file name: 4499338915.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 72), (20, 392)
# Image file name: 144503924.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 38), (12, 234)
# Image file name: 2451569770.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 242), (208, 413)
# Image file name: 390321909.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 13), (5, 89)
# Image file name: 4761260517.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 43), (122, 358)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 83), (63, 130)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 91), (288, 125)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 182), (63, 229)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 192), (291, 225)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 285), (61, 317)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 285), (298, 324)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 377), (292, 421)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (3, 383), (55, 416)
# Image file name: 2403699729.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 27), (5, 342)
# Image file name: 3005794070.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 233), (9, 474)
# Image file name: 4061203190.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 181), (48, 260)
# Image file name: 4605631045.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 347), (126, 446)
# Image file name: 4763207899.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 40), (9, 98)
# Image file name: 4763207899.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 44), (286, 84)
# Image file name: 4763207899.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 161), (11, 217)
# Image file name: 4763207899.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 169), (290, 211)
# Image file name: 4763207899.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 285), (303, 337)
# Image file name: 4763207899.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 287), (4, 327)
# Image file name: 4763207899.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 396), (298, 451)
# Image file name: 4763207899.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 405), (5, 446)
# Image file name: 2534155497.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 59), (1, 479)
# Image file name: 3007885565.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 221), (20, 476)
# Image file name: 4336482746.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 16), (194, 246)
# Image file name: 451265524.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 195), (179, 244)
# Image file name: 791925651.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 1), (3, 96)
# Image file name: 1230939811.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 129), (326, 257)
# Image file name: 1230939811.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 137), (336, 243)
# Image file name: 2550056374.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 18), (2, 488)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 126), (252, 207)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 127), (324, 206)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 129), (109, 206)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 132), (176, 206)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 212), (111, 287)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 213), (180, 288)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 213), (253, 290)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 213), (327, 287)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 294), (109, 373)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 294), (327, 372)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 295), (252, 372)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 296), (179, 370)
# Image file name: 4061203382.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 155), (206, 241)
# Image file name: 4499338915.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 72), (20, 392)
# Image file name: 144503924.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 38), (12, 234)
# Image file name: 2451569770.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 242), (208, 413)
# Image file name: 390321909.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 13), (5, 89)
# Image file name: 4761260517.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 43), (122, 358)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 83), (63, 130)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 91), (288, 125)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 182), (63, 229)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 192), (291, 225)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 285), (61, 317)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 285), (298, 324)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 377), (292, 421)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (4, 383), (55, 416)
# Image file name: 145074777.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 22), (52, 471)
# Image file name: 3732387125.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 415), (87, 430)
# Image file name: 4763209871.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 88), (66, 139)
# Image file name: 4763209871.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 105), (275, 132)
# Image file name: 4763209871.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 185), (67, 230)
# Image file name: 4763209871.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 197), (278, 227)
# Image file name: 4763209871.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 276), (288, 322)
# Image file name: 4763209871.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 285), (62, 315)
# Image file name: 4763209871.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 365), (284, 406)
# Image file name: 4763209871.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 373), (61, 410)
# Image file name: 4763847308.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 35), (3, 97)
# Image file name: 4763847308.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 49), (286, 90)
# Image file name: 4763847308.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 158), (7, 219)
# Image file name: 4763847308.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 169), (287, 213)
# Image file name: 4763847308.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 282), (296, 339)
# Image file name: 4763847308.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 286), (5, 324)
# Image file name: 4763847308.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 393), (295, 450)
# Image file name: 4763847308.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 407), (2, 446)
# Image file name: 7787186.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 67), (16, 440)
# Image file name: 2403699729.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 27), (5, 342)
# Image file name: 3005794070.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 233), (9, 474)
# Image file name: 4061203190.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 181), (48, 260)
# Image file name: 4605631045.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 347), (126, 446)
# Image file name: 4763207899.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 40), (9, 98)
# Image file name: 4763207899.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 44), (286, 84)
# Image file name: 4763207899.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 161), (11, 217)
# Image file name: 4763207899.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 169), (290, 211)
# Image file name: 4763207899.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 285), (303, 337)
# Image file name: 4763207899.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 287), (4, 327)
# Image file name: 4763207899.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 396), (298, 451)
# Image file name: 4763207899.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 405), (5, 446)
# Image file name: 2534155497.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 59), (1, 479)
# Image file name: 3007885565.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 221), (20, 476)
# Image file name: 4336482746.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 16), (194, 246)
# Image file name: 451265524.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 195), (179, 244)
# Image file name: 791925651.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 1), (3, 96)
# Image file name: 1230939811.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 129), (326, 257)
# Image file name: 1230939811.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 137), (336, 243)
# Image file name: 2550056374.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 18), (2, 488)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 126), (252, 207)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 127), (324, 206)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 129), (109, 206)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 132), (176, 206)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 212), (111, 287)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 213), (180, 288)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 213), (253, 290)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 213), (327, 287)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 294), (109, 373)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 294), (327, 372)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 295), (252, 372)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 296), (179, 370)
# Image file name: 4061203382.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 155), (206, 241)
# Image file name: 4499338915.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 72), (20, 392)
# Image file name: 144503924.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 38), (12, 234)
# Image file name: 2451569770.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 242), (208, 413)
# Image file name: 390321909.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 13), (5, 89)
# Image file name: 4761260517.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 43), (122, 358)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 83), (63, 130)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 91), (288, 125)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 182), (63, 229)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 192), (291, 225)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 285), (61, 317)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 285), (298, 324)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 377), (292, 421)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (5, 383), (55, 416)
# Image file name: 2450743885.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 49), (13, 305)
# Image file name: 2553832700.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 4), (5, 499)
# Image file name: 3308750600.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 10), (153, 159)
# Image file name: 3541292073.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 217), (92, 271)
# Image file name: 4061675184.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 274), (132, 326)
# Image file name: 145074777.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 22), (52, 471)
# Image file name: 3732387125.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 415), (87, 430)
# Image file name: 4763209871.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 88), (66, 139)
# Image file name: 4763209871.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 105), (275, 132)
# Image file name: 4763209871.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 185), (67, 230)
# Image file name: 4763209871.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 197), (278, 227)
# Image file name: 4763209871.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 276), (288, 322)
# Image file name: 4763209871.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 285), (62, 315)
# Image file name: 4763209871.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 365), (284, 406)
# Image file name: 4763209871.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 373), (61, 410)
# Image file name: 4763847308.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 35), (3, 97)
# Image file name: 4763847308.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 49), (286, 90)
# Image file name: 4763847308.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 158), (7, 219)
# Image file name: 4763847308.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 169), (287, 213)
# Image file name: 4763847308.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 282), (296, 339)
# Image file name: 4763847308.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 286), (5, 324)
# Image file name: 4763847308.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 393), (295, 450)
# Image file name: 4763847308.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 407), (2, 446)
# Image file name: 7787186.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 67), (16, 440)
# Image file name: 2403699729.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 27), (5, 342)
# Image file name: 3005794070.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 233), (9, 474)
# Image file name: 4061203190.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 181), (48, 260)
# Image file name: 4605631045.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 347), (126, 446)
# Image file name: 4763207899.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 40), (9, 98)
# Image file name: 4763207899.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 44), (286, 84)
# Image file name: 4763207899.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 161), (11, 217)
# Image file name: 4763207899.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 169), (290, 211)
# Image file name: 4763207899.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 285), (303, 337)
# Image file name: 4763207899.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 287), (4, 327)
# Image file name: 4763207899.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 396), (298, 451)
# Image file name: 4763207899.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 405), (5, 446)
# Image file name: 2534155497.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 59), (1, 479)
# Image file name: 3007885565.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 221), (20, 476)
# Image file name: 4336482746.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 16), (194, 246)
# Image file name: 451265524.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 195), (179, 244)
# Image file name: 791925651.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 1), (3, 96)
# Image file name: 1230939811.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 129), (326, 257)
# Image file name: 1230939811.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 137), (336, 243)
# Image file name: 2550056374.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 18), (2, 488)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 126), (252, 207)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 127), (324, 206)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 129), (109, 206)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 132), (176, 206)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 212), (111, 287)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 213), (180, 288)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 213), (253, 290)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 213), (327, 287)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 294), (109, 373)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 294), (327, 372)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 295), (252, 372)
# Image file name: 3294282629.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 296), (179, 370)
# Image file name: 4061203382.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 155), (206, 241)
# Image file name: 4499338915.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 72), (20, 392)
# Image file name: 144503924.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 38), (12, 234)
# Image file name: 2451569770.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 242), (208, 413)
# Image file name: 390321909.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 13), (5, 89)
# Image file name: 4761260517.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 43), (122, 358)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 83), (63, 130)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 91), (288, 125)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 182), (63, 229)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 192), (291, 225)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 285), (61, 317)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 285), (298, 324)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 377), (292, 421)
# Image file name: 4763210295.jpg
# Class label: Adidas
# Bounding box coordinates: (6, 383), (55, 416)
# Image file name: 3006946827.jpg
# Class label: Apple
# Bounding box coordinates: (1, 79), (17, 444)
# Image file name: 3065654531.jpg
# Class label: Apple
# Bounding box coordinates: (1, 84), (134, 252)
# Image file name: 3190306185.jpg
# Class label: Apple
# Bounding box coordinates: (1, 321), (257, 373)
# Image file name: 3261774945.jpg
# Class label: Apple
# Bounding box coordinates: (1, 64), (20, 397)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (1, 12), (127, 74)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (1, 41), (62, 143)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (1, 80), (5, 206)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (1, 186), (155, 227)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (1, 225), (155, 252)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (1, 227), (248, 262)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (1, 229), (201, 262)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (1, 247), (227, 270)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (1, 252), (191, 275)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (1, 253), (301, 280)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (1, 276), (290, 292)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (1, 283), (269, 302)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (1, 284), (10, 316)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (1, 287), (307, 314)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (1, 297), (291, 312)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (1, 304), (277, 321)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (1, 309), (297, 326)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (1, 325), (240, 346)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (1, 329), (299, 351)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (1, 334), (65, 361)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (1, 350), (232, 379)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (1, 356), (58, 389)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (1, 371), (280, 396)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (1, 395), (291, 423)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (1, 406), (159, 419)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (1, 438), (276, 462)
# Image file name: 2401584750.jpg
# Class label: Apple
# Bounding box coordinates: (2, 107), (18, 390)
# Image file name: 299768792.jpg
# Class label: Apple
# Bounding box coordinates: (2, 126), (68, 415)
# Image file name: 3023420658.jpg
# Class label: Apple
# Bounding box coordinates: (2, 171), (115, 298)
# Image file name: 4210274024.jpg
# Class label: Apple
# Bounding box coordinates: (2, 143), (13, 384)
# Image file name: 442337651.jpg
# Class label: Apple
# Bounding box coordinates: (2, 178), (60, 324)
# Image file name: 3006946827.jpg
# Class label: Apple
# Bounding box coordinates: (2, 79), (17, 444)
# Image file name: 3065654531.jpg
# Class label: Apple
# Bounding box coordinates: (2, 84), (134, 252)
# Image file name: 3190306185.jpg
# Class label: Apple
# Bounding box coordinates: (2, 321), (257, 373)
# Image file name: 3261774945.jpg
# Class label: Apple
# Bounding box coordinates: (2, 64), (20, 397)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (2, 12), (127, 74)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (2, 41), (62, 143)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (2, 80), (5, 206)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (2, 186), (155, 227)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (2, 225), (155, 252)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (2, 227), (248, 262)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (2, 229), (201, 262)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (2, 247), (227, 270)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (2, 252), (191, 275)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (2, 253), (301, 280)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (2, 276), (290, 292)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (2, 283), (269, 302)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (2, 284), (10, 316)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (2, 287), (307, 314)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (2, 297), (291, 312)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (2, 304), (277, 321)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (2, 309), (297, 326)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (2, 325), (240, 346)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (2, 329), (299, 351)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (2, 334), (65, 361)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (2, 350), (232, 379)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (2, 356), (58, 389)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (2, 371), (280, 396)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (2, 395), (291, 423)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (2, 406), (159, 419)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (2, 438), (276, 462)
# Image file name: 2274089022.jpg
# Class label: Apple
# Bounding box coordinates: (3, 178), (47, 313)
# Image file name: 4181108300.jpg
# Class label: Apple
# Bounding box coordinates: (3, 152), (271, 170)
# Image file name: 418635708.jpg
# Class label: Apple
# Bounding box coordinates: (3, 4), (5, 176)
# Image file name: 4211723460.jpg
# Class label: Apple
# Bounding box coordinates: (3, 130), (208, 187)
# Image file name: 4749057567.jpg
# Class label: Apple
# Bounding box coordinates: (3, 41), (19, 468)
# Image file name: 2401584750.jpg
# Class label: Apple
# Bounding box coordinates: (3, 107), (18, 390)
# Image file name: 299768792.jpg
# Class label: Apple
# Bounding box coordinates: (3, 126), (68, 415)
# Image file name: 3023420658.jpg
# Class label: Apple
# Bounding box coordinates: (3, 171), (115, 298)
# Image file name: 4210274024.jpg
# Class label: Apple
# Bounding box coordinates: (3, 143), (13, 384)
# Image file name: 442337651.jpg
# Class label: Apple
# Bounding box coordinates: (3, 178), (60, 324)
# Image file name: 3006946827.jpg
# Class label: Apple
# Bounding box coordinates: (3, 79), (17, 444)
# Image file name: 3065654531.jpg
# Class label: Apple
# Bounding box coordinates: (3, 84), (134, 252)
# Image file name: 3190306185.jpg
# Class label: Apple
# Bounding box coordinates: (3, 321), (257, 373)
# Image file name: 3261774945.jpg
# Class label: Apple
# Bounding box coordinates: (3, 64), (20, 397)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (3, 12), (127, 74)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (3, 41), (62, 143)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (3, 80), (5, 206)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (3, 186), (155, 227)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (3, 225), (155, 252)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (3, 227), (248, 262)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (3, 229), (201, 262)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (3, 247), (227, 270)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (3, 252), (191, 275)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (3, 253), (301, 280)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (3, 276), (290, 292)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (3, 283), (269, 302)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (3, 284), (10, 316)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (3, 287), (307, 314)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (3, 297), (291, 312)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (3, 304), (277, 321)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (3, 309), (297, 326)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (3, 325), (240, 346)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (3, 329), (299, 351)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (3, 334), (65, 361)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (3, 350), (232, 379)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (3, 356), (58, 389)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (3, 371), (280, 396)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (3, 395), (291, 423)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (3, 406), (159, 419)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (3, 438), (276, 462)
# Image file name: 2425891764.jpg
# Class label: Apple
# Bounding box coordinates: (4, 6), (6, 450)
# Image file name: 339296129.jpg
# Class label: Apple
# Bounding box coordinates: (4, 106), (56, 400)
# Image file name: 3513049256.jpg
# Class label: Apple
# Bounding box coordinates: (4, 179), (65, 304)
# Image file name: 3766774652.jpg
# Class label: Apple
# Bounding box coordinates: (4, 86), (41, 400)
# Image file name: 4211723816.jpg
# Class label: Apple
# Bounding box coordinates: (4, 110), (157, 175)
# Image file name: 2274089022.jpg
# Class label: Apple
# Bounding box coordinates: (4, 178), (47, 313)
# Image file name: 4181108300.jpg
# Class label: Apple
# Bounding box coordinates: (4, 152), (271, 170)
# Image file name: 418635708.jpg
# Class label: Apple
# Bounding box coordinates: (4, 4), (5, 176)
# Image file name: 4211723460.jpg
# Class label: Apple
# Bounding box coordinates: (4, 130), (208, 187)
# Image file name: 4749057567.jpg
# Class label: Apple
# Bounding box coordinates: (4, 41), (19, 468)
# Image file name: 2401584750.jpg
# Class label: Apple
# Bounding box coordinates: (4, 107), (18, 390)
# Image file name: 299768792.jpg
# Class label: Apple
# Bounding box coordinates: (4, 126), (68, 415)
# Image file name: 3023420658.jpg
# Class label: Apple
# Bounding box coordinates: (4, 171), (115, 298)
# Image file name: 4210274024.jpg
# Class label: Apple
# Bounding box coordinates: (4, 143), (13, 384)
# Image file name: 442337651.jpg
# Class label: Apple
# Bounding box coordinates: (4, 178), (60, 324)
# Image file name: 3006946827.jpg
# Class label: Apple
# Bounding box coordinates: (4, 79), (17, 444)
# Image file name: 3065654531.jpg
# Class label: Apple
# Bounding box coordinates: (4, 84), (134, 252)
# Image file name: 3190306185.jpg
# Class label: Apple
# Bounding box coordinates: (4, 321), (257, 373)
# Image file name: 3261774945.jpg
# Class label: Apple
# Bounding box coordinates: (4, 64), (20, 397)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (4, 12), (127, 74)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (4, 41), (62, 143)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (4, 80), (5, 206)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (4, 186), (155, 227)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (4, 225), (155, 252)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (4, 227), (248, 262)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (4, 229), (201, 262)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (4, 247), (227, 270)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (4, 252), (191, 275)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (4, 253), (301, 280)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (4, 276), (290, 292)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (4, 283), (269, 302)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (4, 284), (10, 316)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (4, 287), (307, 314)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (4, 297), (291, 312)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (4, 304), (277, 321)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (4, 309), (297, 326)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (4, 325), (240, 346)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (4, 329), (299, 351)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (4, 334), (65, 361)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (4, 350), (232, 379)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (4, 356), (58, 389)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (4, 371), (280, 396)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (4, 395), (291, 423)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (4, 406), (159, 419)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (4, 438), (276, 462)
# Image file name: 2270013615.jpg
# Class label: Apple
# Bounding box coordinates: (5, 335), (80, 489)
# Image file name: 2795236586.jpg
# Class label: Apple
# Bounding box coordinates: (5, 183), (131, 312)
# Image file name: 3187422169.jpg
# Class label: Apple
# Bounding box coordinates: (5, 112), (289, 225)
# Image file name: 3652933741.jpg
# Class label: Apple
# Bounding box coordinates: (5, 109), (64, 393)
# Image file name: 470289641.jpg
# Class label: Apple
# Bounding box coordinates: (5, 133), (108, 188)
# Image file name: 470289641.jpg
# Class label: Apple
# Bounding box coordinates: (5, 145), (357, 195)
# Image file name: 2425891764.jpg
# Class label: Apple
# Bounding box coordinates: (5, 6), (6, 450)
# Image file name: 339296129.jpg
# Class label: Apple
# Bounding box coordinates: (5, 106), (56, 400)
# Image file name: 3513049256.jpg
# Class label: Apple
# Bounding box coordinates: (5, 179), (65, 304)
# Image file name: 3766774652.jpg
# Class label: Apple
# Bounding box coordinates: (5, 86), (41, 400)
# Image file name: 4211723816.jpg
# Class label: Apple
# Bounding box coordinates: (5, 110), (157, 175)
# Image file name: 2274089022.jpg
# Class label: Apple
# Bounding box coordinates: (5, 178), (47, 313)
# Image file name: 4181108300.jpg
# Class label: Apple
# Bounding box coordinates: (5, 152), (271, 170)
# Image file name: 418635708.jpg
# Class label: Apple
# Bounding box coordinates: (5, 4), (5, 176)
# Image file name: 4211723460.jpg
# Class label: Apple
# Bounding box coordinates: (5, 130), (208, 187)
# Image file name: 4749057567.jpg
# Class label: Apple
# Bounding box coordinates: (5, 41), (19, 468)
# Image file name: 2401584750.jpg
# Class label: Apple
# Bounding box coordinates: (5, 107), (18, 390)
# Image file name: 299768792.jpg
# Class label: Apple
# Bounding box coordinates: (5, 126), (68, 415)
# Image file name: 3023420658.jpg
# Class label: Apple
# Bounding box coordinates: (5, 171), (115, 298)
# Image file name: 4210274024.jpg
# Class label: Apple
# Bounding box coordinates: (5, 143), (13, 384)
# Image file name: 442337651.jpg
# Class label: Apple
# Bounding box coordinates: (5, 178), (60, 324)
# Image file name: 3006946827.jpg
# Class label: Apple
# Bounding box coordinates: (5, 79), (17, 444)
# Image file name: 3065654531.jpg
# Class label: Apple
# Bounding box coordinates: (5, 84), (134, 252)
# Image file name: 3190306185.jpg
# Class label: Apple
# Bounding box coordinates: (5, 321), (257, 373)
# Image file name: 3261774945.jpg
# Class label: Apple
# Bounding box coordinates: (5, 64), (20, 397)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (5, 12), (127, 74)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (5, 41), (62, 143)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (5, 80), (5, 206)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (5, 186), (155, 227)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (5, 225), (155, 252)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (5, 227), (248, 262)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (5, 229), (201, 262)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (5, 247), (227, 270)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (5, 252), (191, 275)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (5, 253), (301, 280)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (5, 276), (290, 292)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (5, 283), (269, 302)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (5, 284), (10, 316)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (5, 287), (307, 314)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (5, 297), (291, 312)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (5, 304), (277, 321)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (5, 309), (297, 326)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (5, 325), (240, 346)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (5, 329), (299, 351)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (5, 334), (65, 361)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (5, 350), (232, 379)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (5, 356), (58, 389)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (5, 371), (280, 396)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (5, 395), (291, 423)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (5, 406), (159, 419)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (5, 438), (276, 462)
# Image file name: 236248972.jpg
# Class label: Apple
# Bounding box coordinates: (6, 205), (118, 292)
# Image file name: 2583801040.jpg
# Class label: Apple
# Bounding box coordinates: (6, 85), (10, 472)
# Image file name: 3125626922.jpg
# Class label: Apple
# Bounding box coordinates: (6, 181), (94, 337)
# Image file name: 354643240.jpg
# Class label: Apple
# Bounding box coordinates: (6, 36), (29, 265)
# Image file name: 4211723698.jpg
# Class label: Apple
# Bounding box coordinates: (6, 14), (112, 120)
# Image file name: 2270013615.jpg
# Class label: Apple
# Bounding box coordinates: (6, 335), (80, 489)
# Image file name: 2795236586.jpg
# Class label: Apple
# Bounding box coordinates: (6, 183), (131, 312)
# Image file name: 3187422169.jpg
# Class label: Apple
# Bounding box coordinates: (6, 112), (289, 225)
# Image file name: 3652933741.jpg
# Class label: Apple
# Bounding box coordinates: (6, 109), (64, 393)
# Image file name: 470289641.jpg
# Class label: Apple
# Bounding box coordinates: (6, 133), (108, 188)
# Image file name: 470289641.jpg
# Class label: Apple
# Bounding box coordinates: (6, 145), (357, 195)
# Image file name: 2425891764.jpg
# Class label: Apple
# Bounding box coordinates: (6, 6), (6, 450)
# Image file name: 339296129.jpg
# Class label: Apple
# Bounding box coordinates: (6, 106), (56, 400)
# Image file name: 3513049256.jpg
# Class label: Apple
# Bounding box coordinates: (6, 179), (65, 304)
# Image file name: 3766774652.jpg
# Class label: Apple
# Bounding box coordinates: (6, 86), (41, 400)
# Image file name: 4211723816.jpg
# Class label: Apple
# Bounding box coordinates: (6, 110), (157, 175)
# Image file name: 2274089022.jpg
# Class label: Apple
# Bounding box coordinates: (6, 178), (47, 313)
# Image file name: 4181108300.jpg
# Class label: Apple
# Bounding box coordinates: (6, 152), (271, 170)
# Image file name: 418635708.jpg
# Class label: Apple
# Bounding box coordinates: (6, 4), (5, 176)
# Image file name: 4211723460.jpg
# Class label: Apple
# Bounding box coordinates: (6, 130), (208, 187)
# Image file name: 4749057567.jpg
# Class label: Apple
# Bounding box coordinates: (6, 41), (19, 468)
# Image file name: 2401584750.jpg
# Class label: Apple
# Bounding box coordinates: (6, 107), (18, 390)
# Image file name: 299768792.jpg
# Class label: Apple
# Bounding box coordinates: (6, 126), (68, 415)
# Image file name: 3023420658.jpg
# Class label: Apple
# Bounding box coordinates: (6, 171), (115, 298)
# Image file name: 4210274024.jpg
# Class label: Apple
# Bounding box coordinates: (6, 143), (13, 384)
# Image file name: 442337651.jpg
# Class label: Apple
# Bounding box coordinates: (6, 178), (60, 324)
# Image file name: 3006946827.jpg
# Class label: Apple
# Bounding box coordinates: (6, 79), (17, 444)
# Image file name: 3065654531.jpg
# Class label: Apple
# Bounding box coordinates: (6, 84), (134, 252)
# Image file name: 3190306185.jpg
# Class label: Apple
# Bounding box coordinates: (6, 321), (257, 373)
# Image file name: 3261774945.jpg
# Class label: Apple
# Bounding box coordinates: (6, 64), (20, 397)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (6, 12), (127, 74)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (6, 41), (62, 143)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (6, 80), (5, 206)
# Image file name: 3733440395.jpg
# Class label: Apple
# Bounding box coordinates: (6, 186), (155, 227)
# Image file name: 3733440395.jpg
# Class label: Apple
# ...
# Image file name: 4152379789.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 209), (414, 255)
# Image file name: 4152379789.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 210), (293, 255)
# Image file name: 4152379789.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 224), (351, 260)
# Image file name: 4152379789.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 237), (34, 288)
# Image file name: 4152379789.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 244), (104, 304)
# Image file name: 4152379789.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 250), (71, 292)
# Image file name: 4152379789.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 252), (155, 307)
# Image file name: 4152379789.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 267), (195, 311)
# Image file name: 4152379789.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 280), (45, 337)
# Image file name: 4152379789.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 281), (297, 318)
# Image file name: 4152379789.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 288), (417, 333)
# Image file name: 4152379789.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 289), (358, 334)
# Image file name: 4152379789.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 293), (86, 353)
# Image file name: 4152379789.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 306), (119, 358)
# Image file name: 4152379789.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 311), (161, 360)
# Image file name: 4152379789.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 322), (207, 365)
# Image file name: 4152379789.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 337), (253, 364)
# Image file name: 4152379789.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 342), (303, 371)
# Image file name: 4177800765.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 1), (4, 40)
# Image file name: 170453766.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 43), (99, 79)
# Image file name: 170453766.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 245), (233, 307)
# Image file name: 170453766.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 443), (279, 454)
# Image file name: 1888260223.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 421), (251, 476)
# Image file name: 2445338870.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 296), (75, 381)
# Image file name: 2620571508.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 4), (9, 308)
# Image file name: 2620571508.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 46), (18, 275)
# Image file name: 4690656866.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 49), (242, 145)
# Image file name: 4690656866.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 222), (167, 304)
# Image file name: 2423655766.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 65), (16, 258)
# Image file name: 2766852637.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 64), (28, 248)
# Image file name: 2767698530.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 73), (18, 221)
# Image file name: 3602903123.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 247), (186, 287)
# Image file name: 3834509832.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 135), (157, 166)
# Image file name: 258770610.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 17), (22, 255)
# Image file name: 258770610.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 76), (33, 201)
# Image file name: 3231989873.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 31), (52, 205)
# Image file name: 332368134.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 279), (217, 496)
# Image file name: 332368134.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 297), (229, 493)
# Image file name: 332368134.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 298), (226, 494)
# Image file name: 332368134.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 308), (223, 494)
# Image file name: 332368134.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 360), (223, 447)
# Image file name: 3705989051.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 30), (3, 98)
# Image file name: 50082240.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 287), (76, 334)
# Image file name: 50082240.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 431), (81, 487)
# Image file name: 2423654138.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 47), (19, 265)
# Image file name: 2656406197.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 41), (299, 62)
# Image file name: 2656406197.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 111), (9, 185)
# Image file name: 3119389772.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 52), (3, 80)
# Image file name: 3817452506.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 36), (4, 113)
# Image file name: 4185986382.jpg
# Class label: Vodafone
# Bounding box coordinates: (6, 1), (91, 226)
# Image file name: 2126991906.jpg
# Class label: Yahoo
# Bounding box coordinates: (1, 15), (6, 253)
# Image file name: 217288720.jpg
# Class label: Yahoo
# Bounding box coordinates: (1, 136), (161, 304)
# Image file name: 2472817996.jpg
# Class label: Yahoo
# Bounding box coordinates: (1, 2), (4, 499)
# Image file name: 2514220918.jpg
# Class label: Yahoo
# Bounding box coordinates: (1, 1), (69, 342)
# Image file name: 386891249.jpg
# Class label: Yahoo
# Bounding box coordinates: (1, 156), (10, 310)
# Image file name: 3797114221.jpg
# Class label: Yahoo
# Bounding box coordinates: (2, 1), (6, 217)
# Image file name: 3905787011.jpg
# Class label: Yahoo
# Bounding box coordinates: (2, 6), (3, 183)
# Image file name: 3972897298.jpg
# Class label: Yahoo
# Bounding box coordinates: (2, 117), (10, 179)
# Image file name: 4120098544.jpg
# Class label: Yahoo
# Bounding box coordinates: (2, 4), (83, 492)
# Image file name: 50471578.jpg
# Class label: Yahoo
# Bounding box coordinates: (2, 1), (2, 221)
# Image file name: 2126991906.jpg
# Class label: Yahoo
# Bounding box coordinates: (2, 15), (6, 253)
# Image file name: 217288720.jpg
# Class label: Yahoo
# Bounding box coordinates: (2, 136), (161, 304)
# Image file name: 2472817996.jpg
# Class label: Yahoo
# Bounding box coordinates: (2, 2), (4, 499)
# Image file name: 2514220918.jpg
# Class label: Yahoo
# Bounding box coordinates: (2, 1), (69, 342)
# Image file name: 386891249.jpg
# Class label: Yahoo
# Bounding box coordinates: (2, 156), (10, 310)
# Image file name: 2727066466.jpg
# Class label: Yahoo
# Bounding box coordinates: (3, 2), (75, 345)
# Image file name: 3002734592.jpg
# Class label: Yahoo
# Bounding box coordinates: (3, 75), (5, 322)
# Image file name: 3107573789.jpg
# Class label: Yahoo
# Bounding box coordinates: (3, 2), (134, 247)
# Image file name: 3950663671.jpg
# Class label: Yahoo
# Bounding box coordinates: (3, 175), (24, 240)
# Image file name: 4682534504.jpg
# Class label: Yahoo
# Bounding box coordinates: (3, 125), (16, 177)
# Image file name: 3797114221.jpg
# Class label: Yahoo
# Bounding box coordinates: (3, 1), (6, 217)
# Image file name: 3905787011.jpg
# Class label: Yahoo
# Bounding box coordinates: (3, 6), (3, 183)
# Image file name: 3972897298.jpg
# Class label: Yahoo
# Bounding box coordinates: (3, 117), (10, 179)
# Image file name: 4120098544.jpg
# Class label: Yahoo
# Bounding box coordinates: (3, 4), (83, 492)
# Image file name: 50471578.jpg
# Class label: Yahoo
# Bounding box coordinates: (3, 1), (2, 221)
# Image file name: 2126991906.jpg
# Class label: Yahoo
# Bounding box coordinates: (3, 15), (6, 253)
# Image file name: 217288720.jpg
# Class label: Yahoo
# Bounding box coordinates: (3, 136), (161, 304)
# Image file name: 2472817996.jpg
# Class label: Yahoo
# Bounding box coordinates: (3, 2), (4, 499)
# Image file name: 2514220918.jpg
# Class label: Yahoo
# Bounding box coordinates: (3, 1), (69, 342)
# Image file name: 386891249.jpg
# Class label: Yahoo
# Bounding box coordinates: (3, 156), (10, 310)
# Image file name: 2263927086.jpg
# Class label: Yahoo
# Bounding box coordinates: (4, 82), (212, 301)
# Image file name: 2792685284.jpg
# Class label: Yahoo
# Bounding box coordinates: (4, 104), (6, 345)
# Image file name: 3854044541.jpg
# Class label: Yahoo
# Bounding box coordinates: (4, 203), (189, 327)
# Image file name: 3854044541.jpg
# Class label: Yahoo
# Bounding box coordinates: (4, 270), (196, 322)
# Image file name: 386891274.jpg
# Class label: Yahoo
# Bounding box coordinates: (4, 151), (10, 308)
# Image file name: 390297596.jpg
# Class label: Yahoo
# Bounding box coordinates: (4, 5), (7, 227)
# Image file name: 2727066466.jpg
# Class label: Yahoo
# Bounding box coordinates: (4, 2), (75, 345)
# Image file name: 3002734592.jpg
# Class label: Yahoo
# Bounding box coordinates: (4, 75), (5, 322)
# Image file name: 3107573789.jpg
# Class label: Yahoo
# Bounding box coordinates: (4, 2), (134, 247)
# Image file name: 3950663671.jpg
# Class label: Yahoo
# Bounding box coordinates: (4, 175), (24, 240)
# Image file name: 4682534504.jpg
# Class label: Yahoo
# Bounding box coordinates: (4, 125), (16, 177)
# Image file name: 3797114221.jpg
# Class label: Yahoo
# Bounding box coordinates: (4, 1), (6, 217)
# Image file name: 3905787011.jpg
# Class label: Yahoo
# Bounding box coordinates: (4, 6), (3, 183)
# Image file name: 3972897298.jpg
# Class label: Yahoo
# Bounding box coordinates: (4, 117), (10, 179)
# Image file name: 4120098544.jpg
# Class label: Yahoo
# Bounding box coordinates: (4, 4), (83, 492)
# Image file name: 50471578.jpg
# Class label: Yahoo
# Bounding box coordinates: (4, 1), (2, 221)
# Image file name: 2126991906.jpg
# Class label: Yahoo
# Bounding box coordinates: (4, 15), (6, 253)
# Image file name: 217288720.jpg
# Class label: Yahoo
# Bounding box coordinates: (4, 136), (161, 304)
# Image file name: 2472817996.jpg
# Class label: Yahoo
# Bounding box coordinates: (4, 2), (4, 499)
# Image file name: 2514220918.jpg
# Class label: Yahoo
# Bounding box coordinates: (4, 1), (69, 342)
# Image file name: 386891249.jpg
# Class label: Yahoo
# Bounding box coordinates: (4, 156), (10, 310)
# Image file name: 2654519236.jpg
# Class label: Yahoo
# Bounding box coordinates: (5, 129), (44, 365)
# Image file name: 2767935306.jpg
# Class label: Yahoo
# Bounding box coordinates: (5, 117), (5, 350)
# Image file name: 3221088943.jpg
# Class label: Yahoo
# Bounding box coordinates: (5, 1), (3, 142)
# Image file name: 4694467394.jpg
# Class label: Yahoo
# Bounding box coordinates: (5, 139), (13, 199)
# Image file name: 82412168.jpg
# Class label: Yahoo
# Bounding box coordinates: (5, 4), (2, 232)
# Image file name: 2263927086.jpg
# Class label: Yahoo
# Bounding box coordinates: (5, 82), (212, 301)
# Image file name: 2792685284.jpg
# Class label: Yahoo
# Bounding box coordinates: (5, 104), (6, 345)
# Image file name: 3854044541.jpg
# Class label: Yahoo
# Bounding box coordinates: (5, 203), (189, 327)
# Image file name: 3854044541.jpg
# Class label: Yahoo
# Bounding box coordinates: (5, 270), (196, 322)
# Image file name: 386891274.jpg
# Class label: Yahoo
# Bounding box coordinates: (5, 151), (10, 308)
# Image file name: 390297596.jpg
# Class label: Yahoo
# Bounding box coordinates: (5, 5), (7, 227)
# Image file name: 2727066466.jpg
# Class label: Yahoo
# Bounding box coordinates: (5, 2), (75, 345)
# Image file name: 3002734592.jpg
# Class label: Yahoo
# Bounding box coordinates: (5, 75), (5, 322)
# Image file name: 3107573789.jpg
# Class label: Yahoo
# Bounding box coordinates: (5, 2), (134, 247)
# Image file name: 3950663671.jpg
# Class label: Yahoo
# Bounding box coordinates: (5, 175), (24, 240)
# Image file name: 4682534504.jpg
# Class label: Yahoo
# Bounding box coordinates: (5, 125), (16, 177)
# Image file name: 3797114221.jpg
# Class label: Yahoo
# Bounding box coordinates: (5, 1), (6, 217)
# Image file name: 3905787011.jpg
# Class label: Yahoo
# Bounding box coordinates: (5, 6), (3, 183)
# Image file name: 3972897298.jpg
# Class label: Yahoo
# Bounding box coordinates: (5, 117), (10, 179)
# Image file name: 4120098544.jpg
# Class label: Yahoo
# Bounding box coordinates: (5, 4), (83, 492)
# Image file name: 50471578.jpg
# Class label: Yahoo
# Bounding box coordinates: (5, 1), (2, 221)
# Image file name: 2126991906.jpg
# Class label: Yahoo
# Bounding box coordinates: (5, 15), (6, 253)
# Image file name: 217288720.jpg
# Class label: Yahoo
# Bounding box coordinates: (5, 136), (161, 304)
# Image file name: 2472817996.jpg
# Class label: Yahoo
# Bounding box coordinates: (5, 2), (4, 499)
# Image file name: 2514220918.jpg
# Class label: Yahoo
# Bounding box coordinates: (5, 1), (69, 342)
# Image file name: 386891249.jpg
# Class label: Yahoo
# Bounding box coordinates: (5, 156), (10, 310)
# Image file name: 2168708196.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 4), (4, 232)
# Image file name: 2990076322.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 40), (310, 281)
# Image file name: 2990076322.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 42), (187, 277)
# Image file name: 2990076322.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 46), (373, 286)
# Image file name: 2990076322.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 48), (67, 278)
# Image file name: 2990076322.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 48), (249, 276)
# Image file name: 2990076322.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 50), (126, 285)
# Image file name: 2990076322.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 54), (2, 277)
# Image file name: 3469867139.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 108), (175, 178)
# Image file name: 3469867139.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 338), (188, 424)
# Image file name: 3992886999.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 80), (194, 170)
# Image file name: 82413169.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 31), (5, 228)
# Image file name: 2654519236.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 129), (44, 365)
# Image file name: 2767935306.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 117), (5, 350)
# Image file name: 3221088943.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 1), (3, 142)
# Image file name: 4694467394.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 139), (13, 199)
# Image file name: 82412168.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 4), (2, 232)
# Image file name: 2263927086.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 82), (212, 301)
# Image file name: 2792685284.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 104), (6, 345)
# Image file name: 3854044541.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 203), (189, 327)
# Image file name: 3854044541.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 270), (196, 322)
# Image file name: 386891274.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 151), (10, 308)
# Image file name: 390297596.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 5), (7, 227)
# Image file name: 2727066466.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 2), (75, 345)
# Image file name: 3002734592.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 75), (5, 322)
# Image file name: 3107573789.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 2), (134, 247)
# Image file name: 3950663671.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 175), (24, 240)
# Image file name: 4682534504.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 125), (16, 177)
# Image file name: 3797114221.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 1), (6, 217)
# Image file name: 3905787011.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 6), (3, 183)
# Image file name: 3972897298.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 117), (10, 179)
# Image file name: 4120098544.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 4), (83, 492)
# Image file name: 50471578.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 1), (2, 221)
# Image file name: 2126991906.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 15), (6, 253)
# Image file name: 217288720.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 136), (161, 304)
# Image file name: 2472817996.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 2), (4, 499)
# Image file name: 2514220918.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 1), (69, 342)
# Image file name: 386891249.jpg
# Class label: Yahoo
# Bounding box coordinates: (6, 156), (10, 310)

# %%
data
# Out:
#                    0       1  2    3    4    5    6
# 0      144503924.jpg  Adidas  1   38   12  234  142
# 1     2451569770.jpg  Adidas  1  242  208  413  331
# 2      390321909.jpg  Adidas  1   13    5   89   60
# 3     4761260517.jpg  Adidas  1   43  122  358  354
# 4     4763210295.jpg  Adidas  1   83   63  130   93
# ...              ...     ... ..  ...  ...  ...  ...
# 4531  2126991906.jpg   Yahoo  6   15    6  253   54
# 4532   217288720.jpg   Yahoo  6  136  161  304  222
# 4533  2472817996.jpg   Yahoo  6    2    4  499  106
# 4534  2514220918.jpg   Yahoo  6    1   69  342  157
# 4535   386891249.jpg   Yahoo  6  156   10  310   49
#
# [4536 rows x 7 columns]

# %% [markdown]
# #### **``Data preprocessing``**

# %% [markdown]
# Load each image and resize it to a fixed size suitable for YOLO input

# %% [markdown]
# 1. Load each image and resize it to a fixed size suitable for YOLO input (416x416 since this is typically used for YOLO)
# 2. Normalize the pixel values of the resized images to the range [0, 1] by dividing by 255.
# 3. Convert the bounding box coordinates from absolute pixel values to relative values with respect to the image dimensions. This whill scale the coordinates to the range [0, 1], where (0,0) represents the top-left corner of the image and (1,1) represents the bottom-right corner.

# %%
folder_path = "/Users/zaravanthoff/Desktop/MasterProject/Datasets/PublicDataset/flickr_logos_27_dataset/flickr_logos_27_dataset_images/"

# %%
# Iterate through each row in the dataset
for index, row in data.iterrows():
    # Extract image filename from the dataset
    image_filename = row[0]  # Accessing by integer index 0
    
    # Construct the full path to the image
    image_path = os.path.join(folder_path, image_filename)
    
    # Read the image using OpenCV
    image = cv2.imread(image_path)

# %%
data
# Out:
#                    0       1  2    3    4    5    6
# 0      144503924.jpg  Adidas  1   38   12  234  142
# 1     2451569770.jpg  Adidas  1  242  208  413  331
# 2      390321909.jpg  Adidas  1   13    5   89   60
# 3     4761260517.jpg  Adidas  1   43  122  358  354
# 4     4763210295.jpg  Adidas  1   83   63  130   93
# ...              ...     ... ..  ...  ...  ...  ...
# 4531  2126991906.jpg   Yahoo  6   15    6  253   54
# 4532   217288720.jpg   Yahoo  6  136  161  304  222
# 4533  2472817996.jpg   Yahoo  6    2    4  499  106
# 4534  2514220918.jpg   Yahoo  6    1   69  342  157
# 4535   386891249.jpg   Yahoo  6  156   10  310   49
#
# [4536 rows x 7 columns]

# %%
# Define the target size for resizing
target_height = 416
target_width = 416

# %%
# List to store resized images and corresponding labels
resized_images = []
labels = []

# %%
# Iterate through each row in the dataset
for index, row in data.iterrows():
    # Extract image filename from the dataset
    image_filename = row[0]  # Accessing by integer index 0
    
    # Construct the full path to the image
    image_path = os.path.join(folder_path, image_filename)
    
    # Read the image using OpenCV
    image = cv2.imread(image_path)
    
    # Resize the image to the target size
    resized_image = cv2.resize(image, (target_width, target_height))
    
    # Append resized image to the list
    resized_images.append(resized_image)
    
    # Append label to the list (assuming label is in the second column of the dataframe)
    label = row[1]
    labels.append(label)

# %%
data
# Out:
#                    0       1  2    3    4    5    6
# 0      144503924.jpg  Adidas  1   38   12  234  142
# 1     2451569770.jpg  Adidas  1  242  208  413  331
# 2      390321909.jpg  Adidas  1   13    5   89   60
# 3     4761260517.jpg  Adidas  1   43  122  358  354
# 4     4763210295.jpg  Adidas  1   83   63  130   93
# ...              ...     ... ..  ...  ...  ...  ...
# 4531  2126991906.jpg   Yahoo  6   15    6  253   54
# 4532   217288720.jpg   Yahoo  6  136  161  304  222
# 4533  2472817996.jpg   Yahoo  6    2    4  499  106
# 4534  2514220918.jpg   Yahoo  6    1   69  342  157
# 4535   386891249.jpg   Yahoo  6  156   10  310   49
#
# [4536 rows x 7 columns]

# %%
# Convert lists to numpy arrays
resized_images = np.array(resized_images)
labels = np.array(labels)

# %%
# Check the shape of resized images and labels
print("Resized Images Shape:", resized_images.shape)
print("Labels Shape:", labels.shape)
# Out:
# Resized Images Shape: (4536, 416, 416, 3)
# Labels Shape: (4536,)

# %%
# Normalize pixel values
resized_images = resized_images.astype('float32') / 255.0

# Check the range of pixel values after normalization
print("Minimum Pixel Value After Normalization:", np.min(resized_images))
print("Maximum Pixel Value After Normalization:", np.max(resized_images))
# Out:
# Minimum Pixel Value After Normalization: 0.0
# Maximum Pixel Value After Normalization: 1.0

# %%
data
# Out:
#                    0       1  2    3    4    5    6
# 0      144503924.jpg  Adidas  1   38   12  234  142
# 1     2451569770.jpg  Adidas  1  242  208  413  331
# 2      390321909.jpg  Adidas  1   13    5   89   60
# 3     4761260517.jpg  Adidas  1   43  122  358  354
# 4     4763210295.jpg  Adidas  1   83   63  130   93
# ...              ...     ... ..  ...  ...  ...  ...
# 4531  2126991906.jpg   Yahoo  6   15    6  253   54
# 4532   217288720.jpg   Yahoo  6  136  161  304  222
# 4533  2472817996.jpg   Yahoo  6    2    4  499  106
# 4534  2514220918.jpg   Yahoo  6    1   69  342  157
# 4535   386891249.jpg   Yahoo  6  156   10  310   49
#
# [4536 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

# Define the ratio for splitting the data
train_ratio = 0.8  # 80% of the data for training
val_ratio = 0.1    # 10% of the data for validation
test_ratio = 0.1   # 10% of the data for testing

# Split the data into training and remaining sets
train_data, remaining_data = train_test_split(data, test_size=(1 - train_ratio), random_state=42)

# Split the remaining data into validation and testing sets
val_data, test_data = train_test_split(remaining_data, test_size=test_ratio/(test_ratio + val_ratio), random_state=42)

# Check the size of each split
print("Training Data Size:", len(train_data))
print("Validation Data Size:", len(val_data))
print("Testing Data Size:", len(test_data))
# Out:
# Training Data Size: 3628
# Validation Data Size: 454
# Testing Data Size: 454

# %%
import tensorflow as tf
from tensorflow.keras import layers

def create_yolo_model(input_shape, num_classes):
    # Define the YOLO model architecture
    inputs = tf.keras.Input(shape=input_shape)

    # Backbone layers (e.g., convolutional layers)
    x = layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same', activation='relu')(inputs)
    x = layers.MaxPooling2D((2, 2), padding='same')(x)
    x = layers.Conv2D(128, (3, 3), strides=(1, 1), padding='same', activation='relu')(x)
    x = layers.MaxPooling2D((2, 2), padding='same')(x)
    x = layers.Conv2D(256, (3, 3), strides=(1, 1), padding='same', activation='relu')(x)
    x = layers.MaxPooling2D((2, 2), padding='same')(x)
    x = layers.Conv2D(512, (3, 3), strides=(1, 1), padding='same', activation='relu')(x)
    x = layers.MaxPooling2D((2, 2), padding='same')(x)
    x = layers.Conv2D(1024, (3, 3), strides=(1, 1), padding='same', activation='relu')(x)
    x = layers.GlobalAveragePooling2D()(x)

    # Detection head (output layer)
    outputs = layers.Dense(num_classes + 5, activation='sigmoid')(x)

    # Create the model
    model = tf.keras.Model(inputs, outputs)

    return model

# Define input shape and number of classes
input_shape = (416, 416, 3)  # Height, Width, Channels
num_classes = 6  # Assuming there are 10 classes (adjust according to your dataset)

# Create the YOLO model
yolo_model = create_yolo_model(input_shape, num_classes)

# Compile the model
yolo_model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

# Print model summary
yolo_model.summary()
# Out:
# 2024-04-05 16:47:21.359978: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2024-04-05 16:47:21.360167: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2024-04-05 16:47:21.360176: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2024-04-05 16:47:21.360219: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-04-05 16:47:21.360615: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 416, 416, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 416, 416, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 208, 208, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 208, 208, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 104, 104, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 104, 104, 256)  │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 52, 52, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 52, 52, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 26, 26, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 26, 26, 1024)   │     4,719,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 11)             │        11,275 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,281,867 (23.96 MB)
#  Trainable params: 6,281,867 (23.96 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
data
# Out:
#                    0       1  2    3    4    5    6
# 0      144503924.jpg  Adidas  1   38   12  234  142
# 1     2451569770.jpg  Adidas  1  242  208  413  331
# 2      390321909.jpg  Adidas  1   13    5   89   60
# 3     4761260517.jpg  Adidas  1   43  122  358  354
# 4     4763210295.jpg  Adidas  1   83   63  130   93
# ...              ...     ... ..  ...  ...  ...  ...
# 4531  2126991906.jpg   Yahoo  6   15    6  253   54
# 4532   217288720.jpg   Yahoo  6  136  161  304  222
# 4533  2472817996.jpg   Yahoo  6    2    4  499  106
# 4534  2514220918.jpg   Yahoo  6    1   69  342  157
# 4535   386891249.jpg   Yahoo  6  156   10  310   49
#
# [4536 rows x 7 columns]

# %%
# Define maximum number of objects that can be detected in an image
max_objects = 10

# Initialize label array with zeros
labels = np.zeros((len(data), max_objects, 5 + num_classes))  # Adjusted to match the number of rows in your dataset

# Create a dictionary to map class labels to indices
class_label_to_index = {}
for idx, label in enumerate(data[1].unique()):  # Assuming class labels are in column 1 of your dataframe
    class_label_to_index[label] = idx

# Iterate over each object in the dataset
for i, row in data.iterrows():
    # Extract bounding box coordinates and class labels from the dataset
    bbox_coords_list = [(row[2], row[3], row[4], row[5])]  # Assuming bbox coordinates are in columns 2 to 5
    class_labels_list = [row[1]]  # Assuming class labels are in column 1

    # Iterate over each object in the image
    for j in range(len(bbox_coords_list)):
        bbox = bbox_coords_list[j]
        class_labels = class_labels_list[j]

        # Encode bounding box coordinates
        x_min, y_min, x_max, y_max = bbox
        labels[i, j, :4] = [x_min, y_min, x_max, y_max]

        # Encode class labels using one-hot encoding
        class_index = class_label_to_index[class_labels]
        labels[i, j, 5 + class_index] = 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[30], line 29
#      27 # Encode class labels using one-hot encoding
#      28 class_index = class_label_to_index[class_labels]
# ---> 29 labels[i, j, 5 + class_index] = 1
#
# IndexError: index 11 is out of bounds for axis 2 with size 11

# %%
# Assuming you have the training and validation data ready (resized images and bounding box annotations)
# Train the model
history = yolo_model.fit(
    x=resized_images, y=labels, batch_size=32, epochs=10, validation_split=0.1
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 3
#       1 # Assuming you have the training and validation data ready (resized images and bounding box annotations)
#       2 # Train the model
# ----> 3 history = yolo_model.fit(
#       4     x=resized_images, y=labels, batch_size=32, epochs=10, validation_split=0.1
#       5 )
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/anaconda3/lib/python3.11/site-packages/optree/ops.py:521, in tree_map(func, tree, is_leaf, none_is_leaf, namespace, *rests)
#     519 flat_args = [leaves] + [treespec.flatten_up_to(r) for r in rests]
#     520 flat_results = map(func, *flat_args)
# --> 521 return treespec.unflatten(flat_results)
#
# ValueError: Invalid dtype: str288

# %%
# # Define training parameters
# batch_size = 32
# epochs = 10
# validation_split = 0.2  # Percentage of training data to use for validation

# # Train the model
# history = yolo_model.fit(
#     resized_images,  # Training data (resized images)
#     labels,  # Training labels
#     batch_size=batch_size,
#     epochs=epochs,
#     validation_split=validation_split
# )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 7
#       4 validation_split = 0.2  # Percentage of training data to use for validation
#       6 # Train the model
# ----> 7 history = yolo_model.fit(
#       8     resized_images,  # Training data (resized images)
#       9     labels,  # Training labels
#      10     batch_size=batch_size,
#      11     epochs=epochs,
#      12     validation_split=validation_split
#      13 )
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/anaconda3/lib/python3.11/site-packages/optree/ops.py:521, in tree_map(func, tree, is_leaf, none_is_leaf, namespace, *rests)
#     519 flat_args = [leaves] + [treespec.flatten_up_to(r) for r in rests]
#     520 flat_results = map(func, *flat_args)
# --> 521 return treespec.unflatten(flat_results)
#
# ValueError: Invalid dtype: str288

# %% [markdown]
# --------------------

# %% [markdown]
# --------------------------
